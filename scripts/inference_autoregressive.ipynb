# %%
import torch
from bubbleformer.models import get_model
from bubbleformer.data import BubblemlForecast

# %%
test_path = ["/share/crsp/lab/ai4ts/share/BubbleML_f32/PoolBoiling-SubCooled-FC72-2D-0.1/Twall-100.hdf5"]
test_dataset = BubblemlForecast(
    filenames=test_path,
    fields=["dfun", "temperature", "velx", "vely"],
    norm="none",
    time_window=10,
    start_time=90
)

# %%
model_name = "avit"
model_kwargs = {
    "fields": 4,
    "time_window": 10,
    "patch_size": 16,
    "embed_dim": 384,
    "processor_blocks": 12,
    "num_heads": 6,
    "drop_path": 0.2,
}
model = get_model(model_name, **model_kwargs)

# %%
from collections import OrderedDict
weights_path = "/pub/sheikhh1/bubbleformer_logs/avit_poolboiling_subcooled_36387447/hpc_ckpt_4.ckpt"
model_data = torch.load(weights_path, weights_only=False)
print(model_data.keys())
diff_term, div_term = model_data['hyper_parameters']['normalization_constants']
diff_term = torch.tensor(diff_term)
div_term = torch.tensor(div_term)
weight_state_dict = OrderedDict()
for key, val in model_data["state_dict"].items():
    name = key[6:]
    weight_state_dict[name] = val
del model_data
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
model.load_state_dict(weight_state_dict)
# Out:
# <All keys matched successfully>

# %%
from bubbleformer.utils.losses import LpLoss
_, _ = test_dataset.normalize(diff_term, div_term)
criterion = LpLoss(d=2, p=2, reduce_dims=[0,1], reductions=["mean", "mean"])
model.eval()
start_time = test_dataset.start_time
skip_itrs = test_dataset.time_window
model_preds = []
model_targets = []
timesteps = []
for itr in range(0, 500, skip_itrs):
    inp, tgt = test_dataset[itr]
    print(f"Autoreg pred {itr}, inp tw [{start_time+itr}, {start_time+itr+skip_itrs}], tgt tw [{start_time+itr+skip_itrs}, {start_time+itr+2*skip_itrs}]")
    if len(model_preds) > 0:
        inp = model_preds[-1] # T, C, H, W
    inp = inp.float().unsqueeze(0)
    pred = model(inp)
    pred = pred.squeeze(0).detach().cpu()
    tgt = tgt.detach().cpu()

    model_preds.append(pred)
    model_targets.append(tgt)
    timesteps.append(torch.arange(start_time+itr+skip_itrs, start_time+itr+2*skip_itrs))
    print(criterion(pred, tgt))
# Out:
# Autoreg pred 0, inp tw [90, 100], tgt tw [100, 110]
# tensor(0.3083)
# Autoreg pred 10, inp tw [100, 110], tgt tw [110, 120]
# tensor(0.3882)
# Autoreg pred 20, inp tw [110, 120], tgt tw [120, 130]
# tensor(0.4211)
# Autoreg pred 30, inp tw [120, 130], tgt tw [130, 140]
# tensor(0.4657)
# Autoreg pred 40, inp tw [130, 140], tgt tw [140, 150]
# tensor(0.4710)
# Autoreg pred 50, inp tw [140, 150], tgt tw [150, 160]
# tensor(0.4974)
# Autoreg pred 60, inp tw [150, 160], tgt tw [160, 170]
# tensor(0.5445)
# Autoreg pred 70, inp tw [160, 170], tgt tw [170, 180]
# tensor(0.6368)
# Autoreg pred 80, inp tw [170, 180], tgt tw [180, 190]
# tensor(0.6739)
# Autoreg pred 90, inp tw [180, 190], tgt tw [190, 200]
# tensor(0.6734)
# Autoreg pred 100, inp tw [190, 200], tgt tw [200, 210]
# tensor(0.6689)
# Autoreg pred 110, inp tw [200, 210], tgt tw [210, 220]
# tensor(0.6977)
# Autoreg pred 120, inp tw [210, 220], tgt tw [220, 230]
# tensor(0.7409)
# Autoreg pred 130, inp tw [220, 230], tgt tw [230, 240]
# tensor(0.7837)
# Autoreg pred 140, inp tw [230, 240], tgt tw [240, 250]
# tensor(0.7574)
# Autoreg pred 150, inp tw [240, 250], tgt tw [250, 260]
# tensor(0.7481)
# Autoreg pred 160, inp tw [250, 260], tgt tw [260, 270]
# tensor(0.7518)
# Autoreg pred 170, inp tw [260, 270], tgt tw [270, 280]
# tensor(0.7573)
# Autoreg pred 180, inp tw [270, 280], tgt tw [280, 290]
# tensor(0.7495)
# Autoreg pred 190, inp tw [280, 290], tgt tw [290, 300]
# tensor(0.7630)
# Autoreg pred 200, inp tw [290, 300], tgt tw [300, 310]
# tensor(0.7521)
# Autoreg pred 210, inp tw [300, 310], tgt tw [310, 320]
# tensor(0.7565)
# Autoreg pred 220, inp tw [310, 320], tgt tw [320, 330]
# tensor(0.8005)
# Autoreg pred 230, inp tw [320, 330], tgt tw [330, 340]
# tensor(0.8253)
# Autoreg pred 240, inp tw [330, 340], tgt tw [340, 350]
# tensor(0.8512)
# Autoreg pred 250, inp tw [340, 350], tgt tw [350, 360]
# tensor(0.8444)
# Autoreg pred 260, inp tw [350, 360], tgt tw [360, 370]
# tensor(0.8023)
# Autoreg pred 270, inp tw [360, 370], tgt tw [370, 380]
# tensor(0.7597)
# Autoreg pred 280, inp tw [370, 380], tgt tw [380, 390]
# tensor(0.7058)
# Autoreg pred 290, inp tw [380, 390], tgt tw [390, 400]
# tensor(0.7112)
# Autoreg pred 300, inp tw [390, 400], tgt tw [400, 410]
# tensor(0.7175)
# Autoreg pred 310, inp tw [400, 410], tgt tw [410, 420]
# tensor(0.7136)
# Autoreg pred 320, inp tw [410, 420], tgt tw [420, 430]
# tensor(0.7133)
# Autoreg pred 330, inp tw [420, 430], tgt tw [430, 440]
# tensor(0.7206)
# Autoreg pred 340, inp tw [430, 440], tgt tw [440, 450]
# tensor(0.7294)
# Autoreg pred 350, inp tw [440, 450], tgt tw [450, 460]
# tensor(0.6978)
# Autoreg pred 360, inp tw [450, 460], tgt tw [460, 470]
# tensor(0.6841)
# Autoreg pred 370, inp tw [460, 470], tgt tw [470, 480]
# tensor(0.7008)
# Autoreg pred 380, inp tw [470, 480], tgt tw [480, 490]
# tensor(0.7107)
# Autoreg pred 390, inp tw [480, 490], tgt tw [490, 500]
# tensor(0.7102)
# Autoreg pred 400, inp tw [490, 500], tgt tw [500, 510]
# tensor(0.6990)
# Autoreg pred 410, inp tw [500, 510], tgt tw [510, 520]
# tensor(0.6975)
# Autoreg pred 420, inp tw [510, 520], tgt tw [520, 530]
# tensor(0.6857)
# Autoreg pred 430, inp tw [520, 530], tgt tw [530, 540]
# tensor(0.6454)
# Autoreg pred 440, inp tw [530, 540], tgt tw [540, 550]
# tensor(0.6517)
# Autoreg pred 450, inp tw [540, 550], tgt tw [550, 560]
# tensor(0.6931)
# Autoreg pred 460, inp tw [550, 560], tgt tw [560, 570]
# tensor(0.8011)
# Autoreg pred 470, inp tw [560, 570], tgt tw [570, 580]
# tensor(0.8125)
# Autoreg pred 480, inp tw [570, 580], tgt tw [580, 590]
# tensor(0.8206)
# Autoreg pred 490, inp tw [580, 590], tgt tw [590, 600]
# tensor(0.8366)

# %%
from bubbleformer.utils.plot_utils import plot_bubbleml

model_preds = torch.cat(model_preds, dim=0)         # T, C, H, W
model_targets = torch.cat(model_targets, dim=0)     # T, C, H, W
timesteps = torch.cat(timesteps, dim=0)             # T,
num_var = len(test_dataset.fields)                  # C

preds = model_preds * div_term.view(1, num_var, 1, 1) + diff_term.view(1, num_var, 1, 1)     # denormalize
targets = model_targets * div_term.view(1, num_var, 1, 1) + diff_term.view(1, num_var, 1, 1) # denormalize

# %%
import os
save_dir = "/pub/sheikhh1/bubbleformer_logs/avit_poolboiling_subcooled_36387447/epoch_200_outputs/sub_100"
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "predictions.pt")

torch.save({"preds": preds, "targets": targets, "timesteps": timesteps}, save_path)
plot_bubbleml(preds, targets, timesteps, save_dir)
# Out:
# 0 files done
# 25 files done
# 50 files done
# 75 files done
# 100 files done
# 125 files done
# 150 files done
# 175 files done
# 200 files done
# 225 files done
# 250 files done
# 275 files done
# 300 files done
# 325 files done
# 350 files done
# 375 files done
# 400 files done
# 425 files done
# 450 files done
# 475 files done

# %%
def get_eikonal_loss(phi):
    """
    phi = predicted sdf torch.Tensor(T,H,W)
    """
    dx = 1/32
    grad_x = (phi[:, :, 2:] - phi[:, :, :-2]) / (2 * dx)
    grad_y = (phi[:, 2:, :] - phi[:, :-2, :]) / (2 * dx)

    grad_x = torch.nn.functional.pad(grad_x, (1, 1), mode="replicate")
    grad_y = torch.nn.functional.pad(grad_y, (0, 0, 1, 1), mode="replicate")

    grad_magnitude = torch.sqrt(grad_x**2 + grad_y**2)
    loss_map = torch.abs(grad_magnitude - 1)
    mean_loss = torch.mean(loss_map, dim=(1, 2))
    return mean_loss

# %%
model_eikonal_loss = get_eikonal_loss(model_preds[:,0,:,:]).numpy()
sim_eikonal_loss = get_eikonal_loss(model_targets[:,0,:,:]).numpy()
timesteps = timesteps.numpy()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(timesteps, sim_eikonal_loss, label='Simulation Eikonal loss')
plt.plot(timesteps, model_eikonal_loss, label='Model Eikonal loss')
plt.xticks(np.arange(100, 600, 50))
plt.xlabel('Time')
plt.ylabel('Loss')
plt.title('Model vs Simulation sdf loss')
plt.legend()
